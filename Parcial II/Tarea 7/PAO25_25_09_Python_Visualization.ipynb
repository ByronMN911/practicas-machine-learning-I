# %% [markdown]
# ![logoitqv1.jpg](attachment:ebb344fc-a652-41c0-b797-98b68e284474.jpg)

# %% [markdown]
# ## 01MIAR- Representación Gráfica

# %% [markdown]
# ![python_logo.png](attachment:3fe4995e-17f1-437f-bde1-98586008baf0.png)

# %% [markdown]
# *Byron Armando Melo Aguilar*

# %% [markdown]
# *[Enlace a Github](https://github.com/ByronMN911/practicas-machine-learning-I/tree/main/Parcial%20II/Tarea%207)*

# %% [markdown]
# **Representacion grafica**
#
# * matplotlib basico (plot, legend, decoradores y anotaciones, grabar)
# * dibujo con pandas (tipos de graficos)
# * intro a seaborn https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# **Referencias**
#
# * https://plotdb.com/
# * https://plotnine.org/
# * https://d3js.org/
# * https://plot.ly/python/
# * https://bokeh.org/
# * https://shiny.rstudio.com/gallery/
# * https://www.tableau.com/es-es

# %% [markdown]
# # matplotlib
#
# * Librería estándar de representación gráfica
# * Low level: fácil de usar, difícil de dominar
# * Control
# * Gráficos y diagramas

# %% [markdown]
# ### Elementos de visualización
#
# * **Gráfico**. Tipo de representación dentro de una subfigura o figura. Existen gran cantidad de tipos de gráficos: barras, líneas, tarta…
# * **Subfigura**. Representación dentro de una figura.
# * **Figura**. Marco donde se representan de manera conjunta una visualización. Se caracterizan por tener un título general y suele tener una descripción así como una fuente o referencia

# %%
# importar matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# * `plot(data)` para crear un gráfico con `data`
# * `show()` para mostrarlo

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['agg', 'auto', 'cairo', 'gtk3', 'gtk3agg', 'gtk3cairo', 'gtk4', 'gtk4agg', 'gtk4cairo', 'inline', 'macosx', 'module://matplotlib_inline.backend_inline', 'nbagg', 'notebook', 'osx', 'pdf', 'pgf', 'ps', 'qt', 'qt5', 'qt5agg', 'qt5cairo', 'qt6', 'qtagg', 'qtcairo', 'svg', 'template', 'tk', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wx', 'wxagg', 'wxcairo']

# %%
# Magic command de Jupyter que configura Matplotlib en modo no interactivo.
# En este modo, los gráficos se muestran como imágenes estáticas dentro
# de la celda del notebook una vez que termina de ejecutarse.
# No es posible hacer zoom, mover el gráfico o actualizarlo dinámicamente.
# %matplotlib inline

# %%
data = np.random.randint(100,size=(3,3))
display(data)
plt.plot(data) # creación del gráfico
plt.show() # comando que muestra los gráficos creados hasta el momento
# Out:
# array([[15, 22, 64],
#        [39, 12, 77],
#        [76, 30, 19]], dtype=int32)

# %%
# Activa el backend interactivo de Matplotlib para Jupyter.
# Los gráficos permiten realizar acciones como:
# - Acercar (zoom).
# - Desplazar (pan).
# - Redimensionar la figura.
# - Actualizar el contenido del gráfico sin volver a dibujarlo por completo.
# %matplotlib notebook

# Desactiva el modo interactivo de Matplotlib.
# Esto evita que cada nueva instrucción de dibujo modifique automáticamente
# el gráfico actual, permitiendo crear varias figuras de forma independiente.
plt.ioff()

# Vuelve a configurar Matplotlib en modo no interactivo.
# A partir de este momento, los gráficos volverán a mostrarse como imágenes
# estáticas dentro del notebook.
# %matplotlib inline

# %%
# Se pueden especificar x e y por separado
x_data = np.arange(75, 100) # dimensiones!
y_data = np.random.randint(80,size=(25))

print(x_data,y_data)

if x_data.size == y_data.size:
    plt.plot(x_data, y_data)
    plt.show()
else:
    print(f"{x_data.size} no tienen las mismas dimensiones {y_data.size}")
# Out:
# [75 76 77 78 79 80 81 82 83 84 85 86 87 88 89 90 91 92 93 94 95 96 97 98
#  99] [ 1 79 69 67 70 56 54  0 66 23 57 62  4 62 69  3 41 33 31 14  0 76 35 24
#  60]

# %% [markdown]
# ## figure, axes
#
# * Figure: objeto en el que residen todos los gráficos (uno o múltiples)
# * Axes: cada uno de los subplots (o gráficos) dentro de Figure

# %%
fig, axes = plt.subplots(3,2) # crea una ndarray de 3x2 axes (o subplots)
print(type(axes))
print(axes.shape)
# Out:
# <class 'numpy.ndarray'>
# (3, 2)

# %%
# Generar los datos
x_data1 = np.arange(0,10)
x_data2 = np.arange(-10,0)
y_data1 = np.random.randint(100,size=(10))
y_data2 = np.random.randint(1000,size=(10))

# %%
# Crear la figura y los subplots
fig, axes = plt.subplots(1,2)
# preparar cada subplot
axes[0].plot(x_data1,y_data1)
axes[1].plot(x_data2,y_data2)

# %%
#mostrar ambos axes
plt.show() # Recomendable usar plt y no fig.show()

# %%
# Crear una figura con un único eje principal (ax)
fig, ax = plt.subplots(1, 1)

# Generar un arreglo con valores desde 0 hasta 11
x = np.arange(12)

# Graficar la primera serie en el eje principal usando el color rojo
ax.plot(x, "r")

# Crear un segundo eje Y que comparte el mismo eje X
# Esto permite mostrar otra gráfica con una escala diferente
ax2 = ax.twinx()

# Graficar la segunda serie (x al cuadrado) en el eje secundario
# utilizando el color verde
ax2.plot(x ** 2, "g")

# Mostrar ambas gráficas en la misma figura
plt.show()

# %%
# Crear la figura y los subplots
fig, axes = plt.subplots(1,2)
# preparar cada subplot
axes[0].plot(x_data1,y_data1)
axes[1].plot(x_data2,y_data2)

# tanto axes como fig pueden configurarse a través de funciones
axes[0].set_ylim([0,1000])
axes[0].set_xlim([-1,12])

axes[0].set_xlabel("Years")
axes[0].set_ylabel("Dollars")

axes[1].set_ylim([0,1000])
axes[1].set_xlim([-11,1])

axes[1].set_xlabel("Years")
axes[1].set_ylabel("Dollars", loc="center", labelpad=-210)

plt.show()

# %% [markdown]
# #### Más métodos
#
# * Documentación general de la [API](https://matplotlib.org/stable/api/index.html)

# %% [markdown]
# # plot()
#
# Múltiples parámetros
#
# ```
# plt.plot(x, y, style, label, linewidth=1, alpha=1)
# ```
#
# * 'style': cadena de texto con formato (color, tipo…) [color][marker][line]
# * 'label': referencia para leyenda
# * 'linewidth': brocha
# * 'alpha': transparencia
#
# Otros: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
y_data = np.random.randint(100,size=(10))
x_data = np.arange(10)

fig,axis = plt.subplots(1,1)
axis.plot(x_data,y_data,'gh--',label='dollars',linewidth=1,alpha=0.6) # creación del gráfico
axis.legend(loc='best') # representar la leyenda
plt.show()

# %% [markdown]
# | Color | Descripción |
# |---|---|
# | b | blue |
# | g | green |
# | r | red |
# | c | cyan |
# | m | magenta |
# | y | yellow |
# | k | black |
# | w | white |

# %% [markdown]
# | Marcador | Descripción |
# |---|---|
# | . | point marker |
# | , | pixel marker |
# | o | circle marker |
# | v | triangle_down marker |
# | ^ | triangle_up marker |
# | < | triangle_left marker |
# | > | triangle_right marker |
# | 1 | tri_down marker |
# | 2 | tri_up marker |
# | 3 | tri_left marker |
# | 4 | tri_right marker |
# | s | square marker |
# | p | pentagon marker |
# | * | star marker |
# | h | hexagon1 marker |
# | H | hexagon2 marker |
# | + | plus marker |
# | x | x marker |
# | D | diamond marker |
# | d | thin_diamond marker |
# | _ | hline marker |

# %% [markdown]
# | Línea | Descripción |
# |---|---|
# | - | solid line style |
# | -- | dashed line style |
# | -. | dash-dot line style |
# | : | dotted line style |

# %% [markdown]
# ### Representar más de un gráfico en una subfigura

# %%
x_data = np.arange(10)
fig,axis = plt.subplots(1,1)
axis.plot(x_data,np.random.randint(100,size=(10)),'go-',label='green',linewidth=1,alpha=0.2) # creación del gráfico
axis.plot(x_data,np.random.randint(100,size=(10)),'bx-.',label='blue',linewidth=1) # creación del gráfico
axis.plot(x_data,np.random.randint(50,80,size=(10)),'rh-.',label='red',linewidth=2, alpha=0.4) # creación del gráfico
axis.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ## Decoradores
#
# Cambian el aspecto general de la figura
#
# ```
# axes.set_xticks(<lista>) #etiquetas del eje
# axes.set_title('titulo') #titulo
# axes.set_ylabel('label')
# axes.set_frame_on(bool)
# ```
#
# [Más métodos](https://matplotlib.org/stable/api/axes_api.html)

# %% [markdown]
# # Anotaciones
#
# Formas de añadir información sobre el gráfico
#
# ```
# axes.text(x,y,'texto')
# axes.annotate(texto, xy, xytext, xycoords, arrowprops)
# ```
#
# [Más métodos](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.annotate.html)

# %%
y_data = np.random.randint(100, size=(10)) # Cuidado con las dimensiones absolutas
x_data = np.arange(10)

# %%
fig,axis = plt.subplots(1,1)
axis.plot(x_data,y_data)
# axis.text(x_data[1],y_data[1],'Low income') # coordenadas igual a los datos
axis.annotate('Low Income', xy=(x_data[1],y_data[1]), xytext=(5, 10), arrowprops = dict(facecolor='red', shrink=1.0)) # anotación completa
plt.show()

# Tipos de gráficos

#Ejemplos disponibles como referencia https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html

# %%
# Horizontal bar
fig, ax = plt.subplots()
# Example data
people = ('PhD', 'MSc', 'BSc', 'N/A')
y_pos = np.arange(len(people))
percentage = [5,45,25,25]

# print(y_pos)
ax.barh(y_pos, percentage, align='center',
        color='green', edgecolor='red')
# Out:
# <BarContainer object of 4 artists>

# %%
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
#ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Percentage of workforce')
ax.set_title('Level of education in the company')

plt.show()

# %%
rects1[2].set_color('#ffcb59')
rects1[1].set_color('#d6ee39')
rects1[0].set_color('#6ade30')

ax.set_yticks(y_pos)
ax.set_yticklabels(cities)

# add some text for labels, title and axes ticks
ax.set_ylabel('Ciudades')
ax.set_xlabel('Km de carril bici')

ax.legend((rects1[0], rects1[1], rects1[2], rects1[3]), cities)

plt.show()

# %%
ls_count = (284487, 244560, 208493, 196764)
cities = ('Madrid', 'Barcelona', 'Sevilla', 'Valencia')
data = np.array(ls_count)/1000
y_pos = np.arange(data.size)

width = 0.35       # the width of the bars
opacity = 0.7

fig, ax = plt.subplots()
rects1 = ax.barh(y_pos, data, width, alpha=opacity)

rects1[3].set_color('#872f29')

# %%
# ============================
# Stack Plot (Gráfico de áreas apiladas)
# ============================

# Valores del eje X (años)
x = [2008, 2009, 2010, 2011, 2012]

# Porcentaje de participación de cada sistema operativo móvil por año
iOS = [35, 25, 20, 17, 18]
Android = [0, 15, 35, 45, 60]
WindowsPhone = [1, 3, 5, 5, 2]
Others = [64, 57, 40, 33, 20]

# Apila todas las listas verticalmente para formar una matriz de NumPy.
# Cada fila representa una categoría (sistema operativo).
# Esta matriz puede utilizarse como entrada para stackplot.
y = np.vstack([iOS, Android, WindowsPhone, Others])

# Muestra la matriz resultante en la consola.
print(y)

# Etiquetas que aparecerán en la leyenda del gráfico.
labels = ["iOS", "Android", "WindowsPhone", "Others"]

# Crea una figura y un eje donde se dibujará el gráfico.
fig, ax = plt.subplots()

# Dibuja el gráfico de áreas apiladas(stackplot).
# Cada lista representa una categoría cuyos valores se acumulan
# sobre la categoría anterior para mostrar la composición del total.
ax.stackplot(x, iOS, Android, WindowsPhone, Others, labels=labels)

# También es posible generar el mismo gráfico utilizando
# la matriz 'y' creada con np.vstack().
# ax.stackplot(x, y, labels=labels)

# Define las posiciones de las marcas (ticks) del eje X.
ax.set_xticks(x)

# Muestra la leyenda en la esquina superior izquierda.
ax.legend(loc='upper left')

# Renderiza y muestra el gráfico en pantalla.
plt.show()
# Out:
# [[35 25 20 17 18]
#  [ 0 15 35 45 60]
#  [ 1  3  5  5  2]
#  [64 57 40 33 20]]

# %%
# ============================
# Scatter Plot (Diagrama de dispersión)
# ============================

# Importa la función rand para generar números aleatorios entre 0 y 1.
from numpy.random import rand

# Crea una figura y un eje donde se dibujará el gráfico.
fig, ax = plt.subplots()

# Número de puntos que tendrá cada grupo de datos.
n = 700

# Recorre una lista de colores para crear tres conjuntos de puntos:
# uno rojo, uno verde y uno azul.
for color in ['red', 'green', 'blue']:

    # Genera dos arreglos de tamaño n con valores aleatorios:
    # x contiene las coordenadas del eje X.
    # y contiene las coordenadas del eje Y.
    x, y = rand(2, n)

    # Genera un tamaño aleatorio para cada punto.
    # Esto hace que algunos marcadores sean más grandes que otros.
    scale = 25.0 * rand(n)

    # Dibuja el conjunto de puntos.
    ax.scatter(
        x, y,                 # Coordenadas de los puntos
        c=color,              # Color del grupo
        s=scale,              # Tamaño de cada punto
        label=color,          # Etiqueta para la leyenda
        alpha=0.3,            # Transparencia (30%)
        edgecolors='none'     # Sin borde alrededor de los puntos
    )

# Muestra la leyenda con los nombres de los grupos.
ax.legend()

# Renderiza y muestra el gráfico en pantalla.
plt.show()

# %% [markdown]
# ## Grabar a archivo (guardar la figura en distintos formatos)
# ```
# # savefig() permite guardar la figura creada con Matplotlib
# # en diferentes formatos como PNG, JPG, PDF, SVG, entre otros.
# #
# # Sintaxis:
# # figure.savefig(
# #     <filename>,      # Nombre y ruta del archivo de salida.
# #     dpi=None,        # Resolución de la imagen (puntos por pulgada).
# #                      # Un valor mayor produce una imagen de mejor calidad.
# #     facecolor='w',   # Color de fondo de la figura ('w' = blanco).
# #     edgecolor='w',   # Color del borde de la figura.
# #     format=None,     # Formato del archivo (png, pdf, svg, jpg, etc.).
# #                      # Si es None, se deduce por la extensión del archivo.
# #     bbox_inches=None # Ajusta el área de la imagen. Usar 'tight' elimina
# #                      # espacios en blanco innecesarios alrededor del gráfico.
# )
# ```
#
# ```
# figure.savefig(
#     <filename>,
#     dpi=None,
#     facecolor='w',
#     edgecolor='w',
#     format=None,
#     bbox_inches=None
# )
# ```

# %%
# guardar la figura (puede ser múltiples gráficos)
import os
ruta = os.path.join("res", "o_figure.png")
fig.savefig(ruta, format='png') # varios formatos aceptados ('pdf','png', 'svg', 'eps'...)

# %% [markdown]
# # Representación gráfica en pandas
#
# * pandas ofrece interfaz para dibujar Series y DataFrame
# * Usa matplotlib internamente
# * Fácil de usar

# %%
rand_matrix = np.random.randint(100,size=(10,3))
frame = pd.DataFrame(rand_matrix, columns=list('AXC'))
frame.plot()
# Out:
# <Axes: >

# %%
plt.show() # aún es necesario llamar a show() para mostrar los gráficos   //TODO encontrar una manera de no usar plt desde pandas

display(frame) # datos en eje x, eje y, leyenda, series?
# Out:
#     A   X   C
# 0  40  37  17
# 1  25  83   6
# 2  51  56  78
# 3  18  87  37
# 4  42  93  45
# 5  23  43  20
# 6  35  68  80
# 7  72  15  36
# 8  67  99  37
# 9  73  94  33

# %% [markdown]
# # frame.plot()
#
# ```
# frame.plot(x,y,label=<Series>,ax,style,kind,xticks,yticks,title,subplots)
# ```
#
# * (solo para Series) label: referencia para la leyenda
# * ax: subfigura en la que dibujar los datos
# * style: estilo de la línea
# * kind: tipo de gráfico ('bar', 'pie', 'hist', 'area' 'line', 'barh', 'density', 'kde').
# * xticks y yticks: valores en los ejes X e Y
# * title: string como título
# * (solo para DataFrame) subplots: bool si se desean subfiguras separadas para cada columna.
# * (solo para DataFrame) 'x' e 'y' se pueden utilizar para seleccionar columnas para cada eje
#
# [Lista completa de argumentos](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)

# %%
rand_matrix = np.random.randint(100, size=(10,3))
frame = pd.DataFrame(rand_matrix, columns=list('ABC'))
frame.plot(style=['r-','g-','b-'], xticks=range(-2,12), title='Random lines', subplots=True)
plt.show()
display(frame)
# Out:
#     A   B   C
# 0  71  89  21
# 1  79  60   0
# 2  35  31  26
# 3  73  13  92
# 4  61  80  76
# 5  80  66  42
# 6  30   6  81
# 7  63  98  71
# 8  46  82  15
# 9   2  51  23

# %%
# combinar pandas plot con matplotlib
rand_matrix = np.random.randint(100, size=(10,3))
frame = pd.DataFrame(rand_matrix, columns=list('ABC'))

fig, axis = plt.subplots(3,1)
ax = frame.plot(style=['r-','g-','b-'], xticks=range(-2,12), title='Random lines', subplots=True, ax=axis)
ax[0].legend(loc='upper left')
plt.show()

# %%
# Gráfico de barras
frame.plot(kind='bar', title='Random lines')
plt.show()

# %%
# Gráfico de área
frame.plot(kind='area', xticks=range(-2,12), title='Random lines')
plt.show()

# %%
# Histogramas
frame.hist()
plt.show()

# %%
# Gráfico de pastel
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],
                    'radius': [2439.7, 6051.8, 6378.1]},
                    index=['Mercury', 'Venus', 'Earth'])
display(df)
df.plot(y='mass', kind='pie', title='Planets') # y variable a usar
plt.show()
# Out:
#          mass  radius
# Mercury  0.33  2439.7
# Venus    4.87  6051.8
# Earth    5.97  6378.1

# %% [markdown]
# # Seaborn
#
# * Abstracción de matplotlib
# * Facilidad de uso y personalización
# * Excelente para exploración y visualización de relaciones entre variables
#
# Viene con varios datasets predefinidos https://github.com/mwaskom/seaborn-data
#
# [Documentación oficial](https://seaborn.pydata.org/)

# %%
import seaborn as sns

# %%
# ============================
# Swarm Plot (Gráfico de enjambre)
# ============================

# Carga el conjunto de datos de ejemplo "flights" incluido en Seaborn.
# Este dataset contiene el número de pasajeros de vuelos por mes y año.
flights_data = sns.load_dataset("flights")

# Muestra el DataFrame completo.
# display(flights_data)

# Construye un gráfico de enjambre (Swarm Plot).
# - x: representa la variable categórica (mes).
# - y: representa la variable numérica (cantidad de pasajeros).
# - data: conjunto de datos que contiene ambas variables.
#
# El Swarm Plot distribuye automáticamente los puntos para evitar que
# se superpongan, permitiendo visualizar la distribución de los datos
# dentro de cada categoría.
sns.swarmplot(x="month", y="passengers", data=flights_data)

# Rota las etiquetas del eje X 90 grados para mejorar su legibilidad.
plt.xticks(rotation=90)

# Renderiza y muestra el gráfico en pantalla.
plt.show()

# %% [markdown]
# **Compatible con pandas**

# %%
# Load in data
tips = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 87        18.28  4.00    Male     No  Thur   Lunch     2
# 97        12.03  1.50    Male    Yes   Fri  Dinner     2
# 60        20.29  3.21    Male    Yes   Sat  Dinner     2
# 32        15.06  3.00  Female     No   Sat  Dinner     2
# 119       24.08  2.92  Female     No  Thur   Lunch     4

# %%
# ============================
# Bar Plot (Gráfico de barras)
# ============================

# Crea un gráfico de barras utilizando el conjunto de datos "tips".
#
# - x='sex': agrupa las barras por sexo (Male y Female).
# - y='tip': calcula y muestra el promedio de la propina para cada grupo.
# - hue='time': divide cada barra según el momento del día (Lunch o Dinner),
#   permitiendo comparar ambas categorías dentro de cada sexo.
# - data=tips: conjunto de datos utilizado para construir el gráfico.
#
# De forma predeterminada, Seaborn representa la media de cada grupo
# e incluye barras de error que muestran un intervalo de confianza
# de la estimación de la media.
#
# El parámetro 'palette' (opcional) permite cambiar la paleta de colores
# utilizada para las barras.
sns.barplot(x='sex', y='tip', hue='time', data=tips)

# Renderiza y muestra el gráfico en pantalla.
plt.show()

# %%
# ============================
# Box Plot (Diagrama de caja y bigotes)
# ============================

# Crea un diagrama de caja para analizar la distribución de las propinas
# según el día de la semana.
#
# - x='day': agrupa los datos por día (Thur, Fri, Sat y Sun).
# - y='tip': representa el valor de las propinas.
# - data=tips: conjunto de datos utilizado para construir el gráfico.
#
# El Box Plot permite visualizar:
# - La mediana (línea dentro de la caja).
# - El primer cuartil (Q1) y el tercer cuartil (Q3), que forman la caja.
# - Los bigotes, que representan la dispersión de los datos.
# - Los valores atípicos (outliers), que aparecen como puntos fuera de los bigotes.
sns.boxplot(x='day', y='tip', data=tips)

# Forma equivalente de crear el mismo gráfico especificando
# directamente las columnas del DataFrame.
# sns.boxplot(x=tips['day'], y=tips.tip)

# Renderiza y muestra el gráfico en pantalla.
plt.show()

# %% [markdown]
# ## Relaciones entre variables
#
# ```
# sns.relplot()
# ```

# %%
tips = sns.load_dataset("tips")
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 177       14.48  2.00    Male    Yes   Sun  Dinner     2
# 118       12.43  1.80  Female     No  Thur   Lunch     2
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 210       30.06  2.00    Male    Yes   Sat  Dinner     3
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4

# %%
sns.relplot(x='total_bill', y='tip', hue='sex', data=tips, kind='scatter')
plt.show()

# %%
# representar la media y la variación de una variable en función de otra
data = sns.load_dataset('flights')
sns.relplot(x="year", y="passengers", kind="line", data=data)
plt.show()

# %%
# relacionar hasta 4 variables automáticamente
sns.relplot(x="total_bill", y="tip", hue="smoker",
            col="sex", height=4,
            kind="scatter",data=tips); #kind ('line','scatter'...)
plt.show()

# %% [markdown]
# ## Distribución de un dataset

# %%
# ============================
# Histograma con curva de densidad (Density Plot)
# ============================

# Crea un gráfico de distribución utilizando la variable 'tip'
# (propinas) del conjunto de datos 'tips'.
#
# - tips['tip']: datos numéricos que se representarán.
# - kde=True: agrega una curva de densidad (Kernel Density Estimate)
#   que muestra la distribución estimada de los datos de forma continua.
# - bins=10: divide los datos en 10 intervalos (contenedores o barras)
#   para construir el histograma.
# - rug=True: añade pequeñas marcas sobre el eje X que indican
#   la posición exacta de cada observación en el conjunto de datos.
sns.displot(tips['tip'], kde=True, bins=10, rug=True)

# Renderiza y muestra el gráfico en pantalla.
plt.show()

# %% [markdown]
# ### Distribución bi-variable
# sns.jointplot(x='total_bill', y='tip', data=tips)
# plt.show()

# %%
# Density plot bi-variable
iris = sns.load_dataset('iris')
display(iris.head(5))
display(iris["species"].unique())
sns.jointplot(x='petal_length', y='petal_width', kind="kde", data=iris)
plt.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <StringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str

# %%
# Relación de cada pareja
sns.pairplot(iris)
plt.show()

# %%
# Relación de cada pareja
sns.pairplot(iris, hue = "species")
plt.show()

# %%
# Scatter plot de las clases del conjunto de datos Iris,
# coloreando cada especie con un color diferente

# Cargar el dataset Iris desde Seaborn
iris = sns.load_dataset('iris')

# Preparación de los datos
data = []
colors = ["red", "green", "blue"]                  # Colores para cada especie
groups = ["setosa", "versicolor", "virginica"]     # Nombres de las especies
columns = ["petal_length", "petal_width"]          # Variables que se graficarán

# Recorrer cada especie para obtener únicamente sus datos
for i in groups:
    # Filtrar el dataset por especie y guardar únicamente
    # las columnas de longitud y ancho del pétalo
    data.append(iris[iris["species"] == i][columns].values)

# Crear la figura y el eje donde se dibujará el gráfico
fig = plt.figure()
ax = fig.add_subplot()

# Graficar los datos de cada especie
for count, d in enumerate(data):

    # Separar las dos variables:
    # x = longitud del pétalo
    # y = ancho del pétalo
    x, y = d[:, 0], d[:, 1]

    # Dibujar los puntos de la especie correspondiente
    ax.scatter(
        x, y,
        alpha=0.4,                     # Transparencia de los puntos
        c=colors[count - 1],           # Color asignado a la especie
        edgecolors='none',             # Sin borde en los marcadores
        s=30,                          # Tamaño de los puntos
        label=groups[count - 1]        # Etiqueta para la leyenda
    )

# Asignar nombres a los ejes
ax.set_xlabel(columns[0])
ax.set_ylabel(columns[1])

# Mostrar la leyenda y el título del gráfico
plt.legend(loc='best')
plt.title('Matplotlib Scatter Plot')

# Mostrar la gráfica en pantalla
plt.show()

# %% [markdown]
# ## Visualización de correlaciones
#
# * Regresión lineal con variables
# * Correlaciones numéricas

# %%
# ============================
# Reg Plot (Gráfico de regresión)
# ============================

# Crea un gráfico de dispersión con una línea de regresión lineal.
#
# - x="total_bill": representa el valor total de la cuenta.
# - y="tip": representa el valor de la propina.
# - data=tips: conjunto de datos utilizado.
#
# El gráfico permite visualizar:
# - La relación (correlación) entre ambas variables.
# - La línea de regresión, que representa la tendencia o modelo
#   de predicción lineal de los datos.
# - La banda sombreada alrededor de la línea, que corresponde
#   al intervalo de confianza de la estimación (95% por defecto).
#
# Si los puntos están más cercanos a la línea de regresión,
# significa que el modelo lineal representa mejor los datos
# y, en general, sus predicciones serán más precisas.
sns.regplot(x="total_bill", y="tip", data=tips)

# Renderiza y muestra el gráfico en pantalla.
plt.show()

# %%
#correlación con valores categóricos (variable discreta, variable debe ser numérica/continua) not a good idea
sns.regplot(x="size", y="tip", data=tips)
plt.show()

# %%
# regresión con polinomios de más grados
sns.regplot(x="petal_length", y="sepal_width", data=iris, order=5)
plt.show()

# %%
# Graficar la relación entre la cuenta total y la propina
# separando los datos según si el cliente es fumador o no
sns.lmplot(
    x="total_bill",      # Variable del eje X
    y="tip",             # Variable del eje Y
    hue="smoker",        # Colorear los puntos según si el cliente fuma
    data=tips,           # Dataset utilizado
    col='time',          # Crear una gráfica para cada momento del día (Lunch y Dinner)
    order=2              # Ajustar una regresión polinómica de grado 2
)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# # Ejercicios
#
# * Representación gráfica con matplotlib y seaborn
#
# ## matplotlib
#
# * crear una lista de años de 2000 a 2020 (eje x)
# * generar datos aleatorios para el eje y (hacerlo 4 veces distintas: y0, y1, y2 e y3)
# * Representar las 4 secuencias de datos aleatorios en una sola figura utilizando matplotlib
# * Añade una leyenda para poder identificar cada secuencia en el gráfico
# * Nombra las secuencias de la siguiente forma: "Hawaii", "San Marino", "Islas Feroe", "Guayana"
# * Representar los mismos datos en 4 subfiguras (axes) distintas, parte de la misma figura
# * Añade la siguiente info:
#     * Título: "Datos aleatorios"
#     * Leyenda
#     * Nombre del eje x: "Año"
#     * Nombre del eje y: "GDP"
# * Añade al menos una anotación (texto y flecha) a uno de los gráficos
#
# ## Seaborn
#
# * Carga los datos de un dataset de seaborn (distinto a 'tips', 'iris' o 'flights') https://github.com/mwaskom/seaborn-data
# * Si para alguno de los ejercicios no encuentras ejemplos en el dataset, busca otro para completarlo
# * Recuerda utilizar la versión 'Raw' si se utiliza la URL en el método read_csv
# * Representa visualmente la relación de cada pareja de atributos (variables)
# * Escoge una pareja (ambos valores contínuos y numéricos) y demuestra su correlación
# * Representa los valores de dos variables (x e y, numéricas) en base a otra variable (categórica)
# * Crea los gráficos que demuestren lo siguiente en el dataset seleccionado:
#     * La distribución de valores (media, distribución, outliers) de una variable numérica contínua
#     * Compara la distribución de esa variable con otra (contínua y numérica) para representar cuantitativamente la densidad de elementos por valor en ambas variables
#     * Muestra un ejemplo en el dataset de una variable a la que un modelo de regresión lineal de orden > 1 sea más ajustado que uno de orden == 1

# %% [markdown]
# # Resolución Ejercicios

# %% [markdown]
# **Ejercicio 1 - MatPlotLib**

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Crear una lista de años de 2000 a 2020 (eje x)
years = np.arange(2000, 2021)

# 2. Generar datos aleatorios para el eje y (4 secuencias distintas)
np.random.seed(42) # Usamos una semilla para resultados reproducibles
y0 = np.random.randint(100, 1000, size=len(years))
y1 = np.random.randint(100, 1000, size=len(years))
y2 = np.random.randint(100, 1000, size=len(years))
y3 = np.random.randint(100, 1000, size=len(years))

# ==========================================
# Representar en una sola figura
# ==========================================
plt.figure(figsize=(20, 5))

# Trazamos indicando el label correspondiente
plt.plot(years, y0, label="Hawaii", marker='o')
plt.plot(years, y1, label="San Marino", marker='s')
plt.plot(years, y2, label="Islas Feroe", marker='^')
plt.plot(years, y3, label="Guayana", marker='d')

plt.title("Evolución del GDP - Figura única")
plt.xlabel("Año")
plt.ylabel("GDP")
plt.xticks(years) # Mostrar todos los años en el eje X
plt.legend()      # Mostrar la leyenda
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()

# ==========================================
# Representar en 4 subfiguras (axes)
# ==========================================
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle("Datos aleatorios", fontsize=16)

# Asignar gráficos a cada subfigura
axes[0, 0].plot(years, y0, color='blue', label="Hawaii")
axes[0, 0].set_title("Hawaii")

axes[0, 1].plot(years, y1, color='orange', label="San Marino")
axes[0, 1].set_title("San Marino")

axes[1, 0].plot(years, y2, color='green', label="Islas Feroe")
axes[1, 0].set_title("Islas Feroe")

axes[1, 1].plot(years, y3, color='red', label="Guayana")
axes[1, 1].set_title("Guayana")

# Anotación (texto y flecha) en uno de los gráficos (Guayana)
idx_max = np.argmax(y3) # Buscamos el índice del valor más alto
axes[1, 1].annotate('Pico Máximo',
                    xy=(years[idx_max], y3[idx_max]), 
                    xytext=(years[idx_max]-5, y3[idx_max]+150),
                    arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=8))

# Aplicar configuraciones globales a cada subfigura
for ax in axes.flat:
    ax.set_xlabel("Año")
    ax.set_ylabel("GDP")
    ax.legend(loc='best')
    ax.grid(True, alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ejercicio 2 - Seaborn**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# 1. Cargar dataset de Seaborn usando la URL Raw (Dataset: Penguins)
url_penguins = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"
df_penguins = pd.read_csv(url_penguins).dropna() # Descartamos nulos para graficar limpiamente

# =========================================================================
# 2. Representa visualmente la relación de cada pareja de atributos
# =========================================================================
sns.pairplot(df_penguins, hue="species")
plt.suptitle("Relaciones entre todas las variables", y=1.02)
plt.show()

# =========================================================================
# 3. Escoge una pareja de valores continuos y demuestra su correlación
# =========================================================================
# Utilizamos 'flipper_length_mm' (aleta) y 'body_mass_g' (peso)
plt.figure(figsize=(8, 5))
sns.regplot(x="flipper_length_mm", y="body_mass_g", data=df_penguins)
plt.title("Correlación: Longitud de aleta vs. Masa corporal")
plt.show()

# =========================================================================
# 4. Dos variables numéricas en base a otra categórica
# =========================================================================
plt.figure(figsize=(8, 5))
# Mostramos largo y ancho del pico, diferenciando por 'island' (isla)
sns.scatterplot(x="bill_length_mm", y="bill_depth_mm", hue="island", data=df_penguins)
plt.title("Dimensiones del pico divididas por Isla (Categórica)")
plt.show()

# =========================================================================
# 5. Distribución (media, distribución, outliers) de variable numérica
# =========================================================================
plt.figure(figsize=(8, 5))
# El diagrama de caja (boxplot) es el mejor para mostrar la mediana, cuartiles y los outliers.
sns.boxplot(x="species", y="body_mass_g", data=df_penguins)
plt.title("Distribución de Masa Corporal por Especie (identificando outliers)")
plt.show()

# =========================================================================
# 6. Compara distribución de variables para densidad (Cuantitativamente)
# =========================================================================
# jointplot con kind='kde' muestra las curvas de nivel topográficas para la densidad
sns.jointplot(x="flipper_length_mm", y="body_mass_g", kind="kde", fill=True, data=df_penguins)
plt.show()

# =========================================================================
# 7. Ejemplo de regresión lineal orden > 1 vs orden == 1
# =========================================================================
# Cambiamos al dataset 'mpg' (rendimiento de autos) porque demuestra a la perfección una curva.
url_mpg = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv"
df_mpg = pd.read_csv(url_mpg).dropna()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Gráfico 1: Regresión de orden 1 (Línea recta) -> Subajustado (Underfitting)
sns.regplot(x="horsepower", y="mpg", data=df_mpg, order=1, ax=axes[0], line_kws={'color':'red'})
axes[0].set_title("Orden = 1 (Ajuste deficiente para la curva)")

# Gráfico 2: Regresión de orden 2 (Curva polinómica) -> Mejor ajustado
sns.regplot(x="horsepower", y="mpg", data=df_mpg, order=2, ax=axes[1], line_kws={'color':'green'})
axes[1].set_title("Orden > 1 (Mejor ajuste polinómico)")

plt.tight_layout()
plt.show()
